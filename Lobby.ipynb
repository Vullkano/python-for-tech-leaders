# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center; text-align: center; font-family: 'Avenir Next LT Pro', sans-serif; padding: 56px 40px; background: linear-gradient(135deg, #0f172a 0%, #1e293b 55%, #0b1220 100%); border-radius: 18px; box-shadow: 0px 14px 30px rgba(0, 0, 0, 0.25); border: 1px solid rgba(148, 163, 184, 0.18); border-bottom: 5px solid #38bdf8;">
#     <p style="margin: 0 0 12px 0; color: #7dd3fc; font-size: 18px; font-weight: 700; letter-spacing: 0.12em; text-transform: uppercase;">Python for Tech Leaders</p>
#     <h1 style="font-size: 54px; font-weight: 800; color: #f8fafc; margin: 0; line-height: 1.05;">Colab Lobby</h1>
#     <p style="font-size: 20px; color: #cbd5e1; max-width: 860px; line-height: 1.6; margin: 20px 0 0 0;">
#         Use this notebook as the entry point to the course material. Here you will find quick access to Colab, the starting point for the content, and a space to keep the next steps organized.
#     </p>
#     <div style="display: flex; flex-wrap: wrap; gap: 14px; justify-content: center; margin-top: 28px;">
#         <a href="https://colab.research.google.com/github/Vullkano/python-for-tech-leaders/blob/main/Lobby.ipynb" style="background: linear-gradient(135deg, #38bdf8, #0ea5e9); color: white; text-decoration: none; padding: 14px 22px; border-radius: 999px; font-size: 16px; font-weight: 700; box-shadow: 0 10px 20px rgba(14, 165, 233, 0.25);">Open in Colab</a>
#         <a href="README.md" style="background: rgba(255, 255, 255, 0.06); color: #e2e8f0; text-decoration: none; padding: 14px 22px; border-radius: 999px; font-size: 16px; font-weight: 700; border: 1px solid rgba(226, 232, 240, 0.16);">View the README</a>
#     </div>
# </div>

# %% [markdown]
# ---
#
# ## What you will find here
#
# - **Colab access**: the button above opens the main notebook in Google Colab.
# - **Course structure**: the notebooks in this repository are organized by topic and progression.
# - **Starting point**: begin with the installation notebook before moving on to the topic notebooks.
#
# ## Project notebooks
#
# - **[0. How to install Python / Python Fundamentals](0.%20How%20to%20install%20Python/Python%20Fundamentals.ipynb)**
# - **[1. Data Structures / Data Structures](1.%20Data%20Structures/Data%20Structures.ipynb)**
# - **[2. Loops / Loops](2.%20Loops/Loops.ipynb)**
