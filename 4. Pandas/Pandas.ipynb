# %% [markdown]
# <div style="display: flex; flex-direction: column; align-items: center; text-align: center; font-family: 'Avenir Next LT Pro', sans-serif; padding: 56px 40px; background: linear-gradient(135deg, #0f172a 0%, #1e293b 55%, #0b1220 100%); border-radius: 18px; box-shadow: 0px 14px 30px rgba(0, 0, 0, 0.25); border: 1px solid rgba(148, 163, 184, 0.18); border-bottom: 5px solid #38bdf8;">
#     <p style="margin: 0 0 12px 0; color: #7dd3fc; font-size: 18px; font-weight: 700; letter-spacing: 0.12em; text-transform: uppercase;">Python for Tech Leaders</p>
#     <h1 style="font-size: 44px; font-weight: 800; color: #f8fafc; margin: 0; line-height: 1.15;">Módulo 4: Introdução ao Pandas</h1>
#     <p style="font-size: 18px; color: #cbd5e1; max-width: 800px; line-height: 1.6; margin: 20px 0 0 0;">
#         Explora a biblioteca de análise de dados mais popular do ecossistema Python. Aprende a ler tabelas de dados, filtrar, agrupar e extrair estatísticas de forma simples e rápida.
#     </p>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="pt">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f4f4;
#             color: #333;
#             margin: 0;
#             padding: 20px;
#             line-height: 1.6;
#         }
#         ol {
#             counter-reset: section;
#             list-style: none;
#             padding-left: 0;
#         }
#         ol > li {
#             counter-increment: section;
#             margin-bottom: 10px;
#             padding-left: 0;
#         }
#         ol > li::before {
#             content: "4." counters(section, ".") " ";
#             font-weight: bold;
#         }
#         a {
#             text-decoration: none;
#             color: #007BFF;
#             font-weight: bold;
#         }
#         a:hover {
#             color: #0056b3;
#         }
#     </style>
# </head>
# <body>
#
# <b><h2>Índice</h2></b>
# <ol start="0">
#     <li><a href="#4.">Pandas com Dataset de Literatura Clássica</a>
#         <ol>
#             <li><a href="#4.1.">Importar e explorar o dataset</a></li>
#             <li><a href="#4.2.">Compreender a estrutura</a></li>
#             <li><a href="#4.3.">Seleção e filtragem</a></li>
#             <li><a href="#4.4.">Agrupamento e estatísticas</a></li>
#             <li><a href="#4.5.">Visualizações com Pandas / Matplotlib</a></li>
#         </ol>
#     </li>
#     <li><a href="#5.">Exercícios Finais</a></li>
# </ol>
#
# </body>
# </html>

# %% [markdown]
# <a class='anchor' id='4.'></a>
# # **4. Pandas com Dataset de [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/)**
#
# Para esta secção, vamos explorar a poderosa biblioteca **Pandas**, uma ferramenta fundamental em ciência de dados para a análise, limpeza e manipulação de dados estruturados.
#
# O principal objetivo aqui é o **processo de aprendizagem**. Para tornar este exercício verdadeiramente enriquecedor, vamos utilizar um conjunto de dados sobre obras literárias clássicas, disponibilizado pelo projeto [CORGIS](https://corgis-edu.github.io/corgis/). Este dataset foi escolhido especificamente por ser **denso, complexo e apresentar algumas lacunas**, tornando-o o cenário perfeito para praticares técnicas reais de exploração e tratamento de dados em falta (*missing values*).
#
# Este dataset inclui informações sobre centenas de textos do Project Gutenberg, tais como:
# - Título e autor da obra;
# - Número de downloads;
# - Métricas de legibilidade (e.g., Flesch-Kincaid, Linsear Write);
# - Análise de sentimentos do texto;
# - Número total de palavras, frases e parágrafos.
#
# Com estes dados desafiadores, o foco será:
# - Investigar padrões e correlações entre diferentes variáveis;
# - Identificar, analisar e tratar as lacunas ou inconsistências estruturais do dataset;
# - Relacionar métricas de complexidade e estilo com o volume de downloads;
# - Criar visualizações e filtros avançados para extrair conhecimento de dados complexos.
#
# A seguir, iremos:
# - Carregar o dataset diretamente da web;
# - Explorar a sua estrutura detalhadamente com pandas;
# - Limpar e tratar as imperfeições dos dados;
# - Aplicar filtros, agrupamentos e métricas úteis para análise estatística e visualização descritiva.

# %%
# !pip install pandas
# Out:
#
# 8b           d8             88  88  88
# `8b         d8'             88  88  88
#  `8b       d8'              88  88  88
#   `8b     d8'  88       88  88  88  88   ,d8   ,adPPYYba,  8b,dPPYba,    ,adPPYba,
#    `8b   d8'   88       88  88  88  88 ,a8"    ""     `Y8  88P'   `"8a  a8"     "8a
#     `8b d8'    88       88  88  88  8888[      ,adPPPPP88  88       88  8b       d8
#      `888'     "8a,   ,a88  88  88  88`"Yba,   88,    ,88  88       88  "8a,   ,a8"
#       `8'       `"YbbdP'Y8  88  88  88   `Y8a  `"8bbdP"Y8  88       88   `"YbbdP"'
#
#
# ...

# %% [markdown]
# <a class='anchor' id='4.1.'></a>
# ## **4.1. Importar e explorar o dataset**

# %%
import pandas as pd

# Carregar o dataset de literatura clássica
url = "https://corgis-edu.github.io/corgis/datasets/csv/classics/classics.csv"
df = pd.read_csv(url)

# Mostrar o dataframe
df
# Out:
#      bibliography.congress classifications bibliography.languages  \
# 0                                       PR                     en
# 1                                       PS                     en
# 2                                    PZ,PR                     en
# 3                                       PR                     en
# 4                                       PT                     en
# ...                                    ...                    ...
# 1001                                   NaN                     en
# 1002                                   NaN                     en
# 1003                                   NaN                     en
# 1004                                   NaN                     en
# 1005                                   NaN                     en
#
#                                   bibliography.subjects  \
# 0     Sisters -- Fiction,Courtship -- Fiction,Social...
# 1     Mentally ill women -- Fiction,Feminist fiction...
# ...

# %% [markdown]
# <a class='anchor' id='4.2.'></a>
# ## **4.2. Compreender a estrutura**

# %%
print(df.shape)       # Exemplo: (Alíneas: 1006, Colunas: 38)
# Out:
# (1006, 38)

# %%
print(df.info())      # Tipos de coluna e valores não-nulos
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 38 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   bibliography.congress classifications            847 non-null    str
#  1   bibliography.languages                           1006 non-null   str
#  2   bibliography.subjects                            851 non-null    str
#  3   bibliography.title                               1006 non-null   str
#  4   bibliography.type                                1006 non-null   str
#  5   metadata.downloads                               1006 non-null   int64
#  6   metadata.id                                      1006 non-null   int64
#  7   metadata.rank                                    1006 non-null   int64
#  8   metadata.url                                     1006 non-null   str
# ...

# %%
print(df.describe())  # Estatísticas como média, mínimo, máximo
# Out:
#        metadata.downloads   metadata.id  metadata.rank  \
# count         1006.000000   1006.000000    1006.000000
# mean          1431.373757  16512.391650     503.500000
# std           2361.420502  18336.804181     290.551487
# min              0.000000      1.000000       1.000000
# 25%            533.000000   1262.000000     252.250000
# 50%            758.500000   8134.000000     503.500000
# 75%           1308.000000  28978.000000     754.750000
# max          36576.000000  51495.000000    1006.000000
#
#        bibliography.author.birth  bibliography.author.death  \
# count                1006.000000                1006.000000
# mean                 1414.925447                1468.493042
# std                   773.309251                 790.256414
# min                  -750.000000                -650.000000
# 25%                  1564.000000                1616.000000
# 50%                  1821.000000                1885.000000
# ...

# %%
df['bibliography.languages'].unique()  # Verificar idiomas disponíveis
# Out:
# <StringArray>
# [    'en',     'de',     'es',     'la',     'tl',     'pt',    'enm',
#  'en,enm',     'fr',  'en,es',     'nl',     'ru',     'it']
# Length: 13, dtype: str

# %% [markdown]
# <a class='anchor' id='4.3.'></a>
# ## **4.3. Seleção e filtragem**

# %%
# Selecionar colunas relevantes
df[['bibliography.title', 'metadata.downloads', 'metrics.sentiments.polarity']]
# Out:
#                             bibliography.title  metadata.downloads  \
# 0                          Pride and Prejudice               36576
# 1                         The Yellow Wallpaper               26363
# 2             Alice's Adventures in Wonderland               18882
# 3      Frankenstein; Or, The Modern Prometheus               17128
# 4                                Metamorphosis               15683
# ...                                        ...                 ...
# 1001                      The Reluctant Heroes                   0
# 1002               Film Truth; September, 1920                   0
# 1003                                    Othmar                   0
# 1004              Church History (Volumes 1-3)                   0
# 1005  The Uncensored Letters of a Canteen Girl                   0
#
#       metrics.sentiments.polarity
# 0                        0.136713
# 1                        0.054174
# 2                        0.041079
# ...

# %%
# Filtrar por idioma (ex.: obras em inglês)
df_en = df[df['bibliography.languages'].str.contains('en')]
df_en
# Out:
#      bibliography.congress classifications bibliography.languages  \
# 0                                       PR                     en
# 1                                       PS                     en
# 2                                    PZ,PR                     en
# 3                                       PR                     en
# 4                                       PT                     en
# ...                                    ...                    ...
# 1001                                   NaN                     en
# 1002                                   NaN                     en
# 1003                                   NaN                     en
# 1004                                   NaN                     en
# 1005                                   NaN                     en
#
#                                   bibliography.subjects  \
# 0     Sisters -- Fiction,Courtship -- Fiction,Social...
# 1     Mentally ill women -- Fiction,Feminist fiction...
# ...

# %% [markdown]
# <a class='anchor' id='4.4.'></a>
# ## **4.4. Agrupamento e estatísticas**

# %%
# Média de downloads por autor
df.groupby('bibliography.author.name')['metadata.downloads'].mean().sort_values(ascending=False).head(10)
# Out:
# bibliography.author.name
# Gilman, Charlotte Perkins       13551.500000
# Machiavelli, Niccolo             9690.000000
# Vatsyayana                       8559.000000
# Douglass, Frederick              6914.000000
# Whitman, Walt                    6899.000000
# Joyce, James                     6808.666667
# Hobbes, Thomas                   6411.000000
# Kafka, Franz                     6390.333333
# Bronte, Emily                    6237.000000
# Shelley, Mary Wollstonecraft     6084.333333
# Name: metadata.downloads, dtype: float64

# %% [markdown]
# <a class='anchor' id='4.5.'></a>
# ## **4.5. Visualizações com Pandas / Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
df['metadata.downloads'].hist(bins=20, color='skyblue')
plt.title('Distribuição de Downloads (obras em inglês)')
plt.xlabel('Downloads')
plt.ylabel('Contagem')
plt.show()

# %%
top10 = df.groupby('bibliography.author.name')['metadata.downloads'].sum().nlargest(10)
top10.plot(kind='barh', figsize=(10, 6), color='teal')
plt.title('Top10 Autores com Mais Downloads')
plt.xlabel('Total de Downloads')
plt.ylabel('Autor')
plt.gca().invert_yaxis()
plt.show()

# %%
df_scatter = df.dropna(subset=['metrics.difficulty.linsear write formula', 'metadata.downloads'])
plt.figure(figsize=(8, 5))
plt.scatter(x=df_scatter['metrics.difficulty.linsear write formula'],
            y=df_scatter['metadata.downloads'],
            alpha=0.6, color='purple')
plt.title('Legibilidade vs. Popularidade')
plt.xlabel('Linsear Write Score')
plt.ylabel('Downloads')
plt.grid(True)
plt.show()

# %% [markdown]
# <a class='anchor' id='5.'></a>
#
# # **5. Exercícios Finais**
# **1.** Para a realização dos exercícios finais, iremos fazer o download da obra completa Dom Casmurro, com o intuito de realizar uma análise detalhada e exploratória deste texto clássico.
# **2.** No segundo exercício, será solicitada uma análise mais aprofundada e complexa sobre o conjunto de dados da [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/), aplicando técnicas avançadas de manipulação e visualização de dados com o Pandas.

# %% [markdown]
# ## **Exercicio 1**
# - Neste exemplo, vamos demonstrar como obter o texto completo da obra Dom Casmurro diretamente do site do Project Gutenberg, utilizando a biblioteca ``requests`` do Python. Esta abordagem permite fazer o download automático do ficheiro de texto para posterior análise e manipulação.

# %%
# !pip install requests
# Out:
#
# 8b           d8             88  88  88
# `8b         d8'             88  88  88
#  `8b       d8'              88  88  88
#   `8b     d8'  88       88  88  88  88   ,d8   ,adPPYYba,  8b,dPPYba,    ,adPPYba,
#    `8b   d8'   88       88  88  88  88 ,a8"    ""     `Y8  88P'   `"8a  a8"     "8a
#     `8b d8'    88       88  88  88  8888[      ,adPPPPP88  88       88  8b       d8
#      `888'     "8a,   ,a88  88  88  88`"Yba,   88,    ,88  88       88  "8a,   ,a8"
#       `8'       `"YbbdP'Y8  88  88  88   `Y8a  `"8bbdP"Y8  88       88   `"YbbdP"'
#
#
# ...

# %%
import requests

url = "https://www.gutenberg.org/ebooks/55752.txt.utf-8"

try:
    resp = requests.get(url, timeout=15)  # timeout de 15 segundos
    resp.encoding = 'utf-8'

    if resp.status_code == 200:
        texto = resp.text
        with open("dom_casmurro.txt", "w", encoding="utf-8") as f:
            f.write(texto)
        print("Ficheiro 'dom_casmurro.txt' criado com sucesso!")
    else:
        print("Erro ao descarregar:", resp.status_code)

except requests.exceptions.ConnectTimeout:
    print("Ligação expirada: o servidor não respondeu a tempo.")
except requests.exceptions.RequestException as e:
    print(f"Erro ao tentar aceder ao recurso: {e}")
# Out:
# Ficheiro 'dom_casmurro.txt' criado com sucesso!

# %%
def limpar_e_atualizar_ficheiro(filepath):
    with open(filepath, encoding='utf-8') as f:
        linhas = f.readlines()
    
    start_idx = 0
    end_idx = len(linhas)
    
    # Encontrar início do texto real
    for i, linha in enumerate(linhas):
        if 'Do titulo.' in linha:
            start_idx = i + 1
            break
    
    # Encontrar fim do texto real
    for i, linha in enumerate(linhas):
        if 'FIM' in linha:
            end_idx = i
            break
    
    # Extrair texto principal e limpar espaços e linhas vazias
    texto_limpo = [linha.strip() for linha in linhas[start_idx:end_idx] if linha.strip()]
    
    # Sobrescrever o ficheiro com o texto limpo
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write("\n".join(texto_limpo))

# Chama a função para atualizar o ficheiro
limpar_e_atualizar_ficheiro("dom_casmurro.txt")

print("Ficheiro 'dom_casmurro.txt' atualizado com texto limpo!")
# Out:
# Ficheiro 'dom_casmurro.txt' atualizado com texto limpo!

# %% [markdown]
# **a) Limpeza do Texto e Contagem de Palavras**
# - **Objetivo**: Limpar o texto, remover pontuação e caracteres especiais, e contar as palavras mais frequentes.

# %% [markdown]
# **b) Análise do Comprimento das Frases**
# - **Objetivo**: Medir quantas palavras tem cada frase e visualizar a variação ao longo do texto.

# %% [markdown]
# **c) Distribuição do Comprimento das Palavras**
# - **Objetivo**: Explorar o comprimento das palavras e visualizar a distribuição.

# %% [markdown]
# **d) Análise das Vogais**
# - **Objetivo**: Contar as vogais no texto e visualizar a distribuição.

# %% [markdown]
# **d) Fazer um WordCloud com as palavras mais importantes**
# - **Objetivo**: Fazer uma visualização das palavras mais frequentes, retirando as stopwords

# %% [markdown]
# ## **Exercicio 2**
# - No segundo exercício, será solicitada uma análise mais aprofundada e complexa sobre o conjunto de dados da [Literatura Clássica](https://corgis-edu.github.io/corgis/csv/classics/), aplicando técnicas de manipulação e visualização de dados com o Pandas.

# %%
# !pip install seaborn matplotlib pandas
# Out:
#
# 8b           d8             88  88  88
# `8b         d8'             88  88  88
#  `8b       d8'              88  88  88
#   `8b     d8'  88       88  88  88  88   ,d8   ,adPPYYba,  8b,dPPYba,    ,adPPYba,
#    `8b   d8'   88       88  88  88  88 ,a8"    ""     `Y8  88P'   `"8a  a8"     "8a
#     `8b d8'    88       88  88  88  8888[      ,adPPPPP88  88       88  8b       d8
#      `888'     "8a,   ,a88  88  88  88`"Yba,   88,    ,88  88       88  "8a,   ,a8"
#       `8'       `"YbbdP'Y8  88  88  88   `Y8a  `"8bbdP"Y8  88       88   `"YbbdP"'
#
#
# ...

# %% [markdown]
# ### Parte I - Pandas

# %% [markdown]
# **a) Carregar o dataset e mostrar as primeiras linhas**
# - Carrega o ficheiro CSV para um DataFrame pandas e mostra as 5 primeiras linhas, e as 5 últimas, para entender a estrutura dos dados.

# %% [markdown]
# **b) Informações gerais e tipos de dados**
# - Analisar a estrutura do dataset, tipos de colunas e valores nulos.

# %% [markdown]
# **c) Limpeza de colunas irrelevantes**
# - Eliminar colunas pouco informativas (ex. ``URLs``, ``IDs``).

# %% [markdown]
# **d) Filtrar livros escritos em inglês**
# - Selecionar apenas os livros cuja língua principal seja o inglês.

# %% [markdown]
# **e) Ordenar por número de downloads**
# - Obter os 10 livros mais descarregados.

# %% [markdown]
# **f) Contar livros por autor**
# - **Objetivo:** Ver que autores têm mais livros no dataset.

# %% [markdown]
# **g) Calcular idade do autor à data de publicação**
# - **Objetivo:** Criar uma nova coluna com a idade do autor aquando da publicação.

# %% [markdown]
# **h) Substituir os valores a zero no Downloads pela mediana**
#
# - **Objetivo:** Substituir valores que são zero pela mediana.

# %% [markdown]
# **i) Criar coluna com número médio de letras por frase**
# - **Objetivo:** Derivar uma nova métrica com base nas estatísticas de caracteres e frases.

# %% [markdown]
# **j) Agrupar por século de publicação**
# - **Objetivo:** Criar uma nova coluna com o século e contar quantas obras há por século.

# %% [markdown]
# ### Parte II - Matplotlib

# %% [markdown]
# **a) Correlação entre dificuldade de leitura e número de palavras**
# - **Objetivo:** Explorar se livros com mais palavras tendem a ser mais difíceis de ler.
# - **Gráfico sugerido:** Diagrama de dispersão (scatterplot).

# %% [markdown]
# **b) Popularidade vs. Facilidade de leitura**
# - **Objetivo:** Ver se os livros mais descarregados são os mais fáceis de ler.
# - **Gráfico sugerido:** Gráfico de dispersão.

# %% [markdown]
# **c) Evolução da complexidade ao longo dos anos**
# - **Objetivo:** Analisar se a dificuldade dos livros aumentou ou diminuiu com os anos de publicação.
# - **Gráfico sugerido:** Gráfico de linhas.

# %% [markdown]
# **d) Dificuldade Média por Autor**
# - **Objetivo:** Identificar quais os autores mais frequentes e comparar a dificuldade média dos seus livros.
# - **Gráfico sugerido:** Gráfico de barras.

# %% [markdown]
# **e) Exploração**
# - **Objetivo:** Usar gráficos para procurar padrões ou correlações entre métricas (tamanho, dificuldade, polaridade, etc.)
